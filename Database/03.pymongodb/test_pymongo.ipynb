# %%
# %pip install pymongo

# %%
from pymongo import MongoClient

# MongoDB 인스턴스에 연결
client = MongoClient('mongodb://localhost:27017/')
client
# Out:
# MongoClient(host=['localhost:27017'], document_class=dict, tz_aware=False, connect=True)

# %%
client = MongoClient('mongodb://username:password@localhost:27017/')

# %%
# 데이터베이스 선택 (없으면 자동 생성)
db = client['example_db']

# %%
# 콜렉션 선택 (없으면 자동 생성)
collection = db['example_collection']
# 새 문서 삽입
example_document = {"name": "John", "age": 30, "city": "New York"}
# 새 문서 삽입
example_document = {"name": "John", "age": 30, "city": "New York"}
collection.insert_many(example_document)

# %%
# 모든 문서 조회
for doc in collection.find():
    print(doc)

# 조건에 맞는 문서 조회
query = {"name": "John"}
for doc in collection.find(query):
    print(doc)
# Out:
# ---------------------------------------------------------------------------
# OperationFailure                          Traceback (most recent call last)
# Cell In[16], line 2
#       1 # 모든 문서 조회
# ----> 2 for doc in collection.find():
#       3     print(doc)
#       5 # 조건에 맞는 문서 조회
#
# File /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/pymongo/synchronous/cursor.py:1281, in Cursor.__next__(self)
#    1280 def __next__(self) -> _DocumentType:
# -> 1281     return self.next()
#
# File /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/pymongo/synchronous/cursor.py:1257, in Cursor.next(self)
#    1255 if self._empty:
#    1256     raise StopIteration
# -> 1257 if len(self._data) or self._refresh():
#    1258     return self._data.popleft()
#    1259 else:
#
# File /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/pymongo/synchronous/cursor.py:1205, in Cursor._refresh(self)
#    1183         raise InvalidOperation(
#    1184             "Passing a 'hint' is required when using the min/max query"
#    1185             " option to ensure the query utilizes the correct index"
#    1186         )
#    1187     q = self._query_class(
#    1188         self._query_flags,
#    1189         self._collection.database.name,
#    (...)
#    1203         self._exhaust,
#    1204     )
# -> 1205     self._send_message(q)
#    1206 elif self._id:  # Get More
#    1207     if self._limit:
#
# File /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/pymongo/synchronous/cursor.py:1100, in Cursor._send_message(self, operation)
#    1097     raise InvalidOperation("exhaust cursors do not support auto encryption")
#    1099 try:
# -> 1100     response = client._run_operation(
#    1101         operation, self._unpack_response, address=self._address
#    1102     )
#    1103 except OperationFailure as exc:
#    1104     if exc.code in _CURSOR_CLOSED_ERRORS or self._exhaust:
#    1105         # Don't send killCursors because the cursor is already closed.
#
# File /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/pymongo/_csot.py:119, in apply.<locals>.csot_wrapper(self, *args, **kwargs)
#     117         with _TimeoutContext(timeout):
#     118             return func(self, *args, **kwargs)
# --> 119 return func(self, *args, **kwargs)
#
# File /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/pymongo/synchronous/mongo_client.py:1754, in MongoClient._run_operation(self, operation, unpack_res, address)
#    1744     operation.reset()  # Reset op in case of retry.
#    1745     return server.run_operation(
#    1746         conn,
#    1747         operation,
#    (...)
#    1751         self,
#    1752     )
# -> 1754 return self._retryable_read(
#    1755     _cmd,
#    1756     operation.read_preference,
#    1757     operation.session,  # type: ignore[arg-type]
#    1758     address=address,
#    1759     retryable=isinstance(operation, _Query),
#    1760     operation=operation.name,
#    1761 )
#
# File /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/pymongo/synchronous/mongo_client.py:1863, in MongoClient._retryable_read(self, func, read_pref, session, operation, address, retryable, operation_id)
#    1858 # Ensure that the client supports retrying on reads and there is no session in
#    1859 # transaction, otherwise, we will not support retry behavior for this call.
#    1860 retryable = bool(
#    1861     retryable and self.options.retry_reads and not (session and session.in_transaction)
#    1862 )
# -> 1863 return self._retry_internal(
#    1864     func,
#    1865     session,
#    1866     None,
#    1867     operation,
#    1868     is_read=True,
#    1869     address=address,
#    1870     read_pref=read_pref,
#    1871     retryable=retryable,
#    1872     operation_id=operation_id,
#    1873 )
#
# File /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/pymongo/_csot.py:119, in apply.<locals>.csot_wrapper(self, *args, **kwargs)
#     117         with _TimeoutContext(timeout):
#     118             return func(self, *args, **kwargs)
# --> 119 return func(self, *args, **kwargs)
#
# File /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/pymongo/synchronous/mongo_client.py:1830, in MongoClient._retry_internal(self, func, session, bulk, operation, is_read, address, read_pref, retryable, operation_id)
#    1793 @_csot.apply
#    1794 def _retry_internal(
#    1795     self,
#    (...)
#    1804     operation_id: Optional[int] = None,
#    1805 ) -> T:
#    1806     """Internal retryable helper for all client transactions.
#    1807
#    1808     :param func: Callback function we want to retry
#    (...)
#    1817     :return: Output of the calling func()
#    1818     """
#    1819     return _ClientConnectionRetryable(
#    1820         mongo_client=self,
#    1821         func=func,
#    1822         bulk=bulk,
#    1823         operation=operation,
#    1824         is_read=is_read,
#    1825         session=session,
#    1826         read_pref=read_pref,
#    1827         address=address,
#    1828         retryable=retryable,
#    1829         operation_id=operation_id,
# -> 1830     ).run()
#
# File /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/pymongo/synchronous/mongo_client.py:2554, in _ClientConnectionRetryable.run(self)
#    2552 self._check_last_error(check_csot=True)
#    2553 try:
# -> 2554     return self._read() if self._is_read else self._write()
#    2555 except ServerSelectionTimeoutError:
#    2556     # The application may think the write was never attempted
#    2557     # if we raise ServerSelectionTimeoutError on the retry
#    2558     # attempt. Raise the original exception instead.
#    2559     self._check_last_error()
#
# File /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/pymongo/synchronous/mongo_client.py:2691, in _ClientConnectionRetryable._read(self)
#    2689 self._server = self._get_server()
#    2690 assert self._read_pref is not None, "Read Preference required on read calls"
# -> 2691 with self._client._conn_from_server(self._read_pref, self._server, self._session) as (
#    2692     conn,
#    2693     read_pref,
#    2694 ):
#    2695     if self._retrying and not self._retryable:
#    2696         self._check_last_error()
#
# File /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/contextlib.py:141, in _GeneratorContextManager.__enter__(self)
#     139 del self.args, self.kwds, self.func
#     140 try:
# --> 141     return next(self.gen)
#     142 except StopIteration:
#     143     raise RuntimeError("generator didn't yield") from None
#
# File /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/pymongo/synchronous/mongo_client.py:1683, in MongoClient._conn_from_server(self, read_preference, server, session)
#    1674 # Get a connection for a server matching the read preference, and yield
#    1675 # conn with the effective read preference. The Server Selection
#    1676 # Spec says not to send any $readPreference to standalones and to
#    (...)
#    1680 # NOTE: We already opened the Topology when selecting a server so there's no need
#    1681 # to call _get_topology() again.
#    1682 single = self._topology.description.topology_type == TOPOLOGY_TYPE.Single
# -> 1683 with self._checkout(server, session) as conn:
#    1684     if single:
#    1685         if conn.is_repl and not (session and session.in_transaction):
#    1686             # Use primary preferred to ensure any repl set member
#    1687             # can handle the request.
#
# File /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/contextlib.py:141, in _GeneratorContextManager.__enter__(self)
#     139 del self.args, self.kwds, self.func
#     140 try:
# --> 141     return next(self.gen)
#     142 except StopIteration:
#     143     raise RuntimeError("generator didn't yield") from None
#
# File /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/pymongo/synchronous/mongo_client.py:1593, in MongoClient._checkout(self, server, session)
#    1591     yield session._pinned_connection
#    1592     return
# -> 1593 with server.checkout(handler=err_handler) as conn:
#    1594     # Pin this session to the selected server or connection.
#    1595     if (
#    1596         in_txn
#    1597         and session
#    (...)
#    1602         )
#    1603     ):
#    1604         session._pin(server, conn)
#
# File /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/contextlib.py:141, in _GeneratorContextManager.__enter__(self)
#     139 del self.args, self.kwds, self.func
#     140 try:
# --> 141     return next(self.gen)
#     142 except StopIteration:
#     143     raise RuntimeError("generator didn't yield") from None
#
# File /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/pymongo/synchronous/pool.py:1336, in Pool.checkout(self, handler)
#    1327 if self.enabled_for_logging and _CONNECTION_LOGGER.isEnabledFor(logging.DEBUG):
#    1328     _debug_log(
#    1329         _CONNECTION_LOGGER,
#    1330         clientId=self._client_id,
#    (...)
#    1333         serverPort=self.address[1],
#    1334     )
# -> 1336 conn = self._get_conn(checkout_started_time, handler=handler)
#    1338 duration = time.monotonic() - checkout_started_time
#    1339 if self.enabled_for_cmap:
#
# File /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/pymongo/synchronous/pool.py:1495, in Pool._get_conn(self, checkout_started_time, handler)
#    1493 else:  # We need to create a new connection
#    1494     try:
# -> 1495         conn = self.connect(handler=handler)
#    1496     finally:
#    1497         with self._max_connecting_cond:
#
# File /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/pymongo/synchronous/pool.py:1296, in Pool.connect(self, handler)
#    1293     if handler:
#    1294         handler.contribute_socket(conn, completed_handshake=False)
# -> 1296     conn.authenticate()
#    1297 except BaseException:
#    1298     conn.close_conn(ConnectionClosedReason.ERROR)
#
# File /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/pymongo/synchronous/pool.py:648, in Connection.authenticate(self, reauthenticate)
#     645 if creds:
#     646     from pymongo.synchronous import auth
# --> 648     auth.authenticate(creds, self, reauthenticate=reauthenticate)
#     649 self.ready = True
#     650 duration = time.monotonic() - self.creation_time
#
# File /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/pymongo/synchronous/auth.py:452, in authenticate(credentials, conn, reauthenticate)
#     450     _authenticate_oidc(credentials, conn, reauthenticate)
#     451 else:
# --> 452     auth_func(credentials, conn)
#
# File /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/pymongo/synchronous/auth.py:356, in _authenticate_default(credentials, conn)
#     354         return _authenticate_scram(credentials, conn, "SCRAM-SHA-256")
#     355     else:
# --> 356         return _authenticate_scram(credentials, conn, "SCRAM-SHA-1")
#     357 else:
#     358     return _authenticate_scram(credentials, conn, "SCRAM-SHA-1")
#
# File /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/pymongo/synchronous/auth.py:95, in _authenticate_scram(credentials, conn, mechanism)
#      93 else:
#      94     nonce, first_bare, cmd = _authenticate_scram_start(credentials, mechanism)
# ---> 95     res = conn.command(source, cmd)
#      97 assert res is not None
#      98 server_first = res["payload"]
#
# File /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/pymongo/synchronous/helpers.py:45, in _handle_reauth.<locals>.inner(*args, **kwargs)
#      42 from pymongo.synchronous.pool import Connection
#      44 try:
# ---> 45     return func(*args, **kwargs)
#      46 except OperationFailure as exc:
#      47     if no_reauth:
#
# File /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/pymongo/synchronous/pool.py:538, in Connection.command(self, dbname, spec, read_preference, codec_options, check, allowable_errors, read_concern, write_concern, parse_write_concern_error, collation, session, client, retryable_write, publish_events, user_fields, exhaust_allowed)
#     536     self._raise_if_not_writable(unacknowledged)
#     537 try:
# --> 538     return command(
#     539         self,
#     540         dbname,
#     541         spec,
#     542         self.is_mongos,
#     543         read_preference,
#     544         codec_options,
#     545         session,
#     546         client,
#     547         check,
#     548         allowable_errors,
#     549         self.address,
#     550         listeners,
#     551         self.max_bson_size,
#     552         read_concern,
#     553         parse_write_concern_error=parse_write_concern_error,
#     554         collation=collation,
#     555         compression_ctx=self.compression_context,
#     556         use_op_msg=self.op_msg_enabled,
#     557         unacknowledged=unacknowledged,
#     558         user_fields=user_fields,
#     559         exhaust_allowed=exhaust_allowed,
#     560         write_concern=write_concern,
#     561     )
#     562 except (OperationFailure, NotPrimaryError):
#     563     raise
#
# File /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/pymongo/synchronous/network.py:218, in command(conn, dbname, spec, is_mongos, read_preference, codec_options, session, client, check, allowable_errors, address, listeners, max_bson_size, read_concern, parse_write_concern_error, collation, compression_ctx, use_op_msg, unacknowledged, user_fields, exhaust_allowed, write_concern)
#     216             client._process_response(response_doc, session)
#     217         if check:
# --> 218             helpers_shared._check_command_response(
#     219                 response_doc,
#     220                 conn.max_wire_version,
#     221                 allowable_errors,
#     222                 parse_write_concern_error=parse_write_concern_error,
#     223             )
#     224 except Exception as exc:
#     225     duration = datetime.datetime.now() - start
#
# File /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/pymongo/helpers_shared.py:247, in _check_command_response(response, max_wire_version, allowable_errors, parse_write_concern_error)
#     244 elif code == 43:
#     245     raise CursorNotFound(errmsg, code, response, max_wire_version)
# --> 247 raise OperationFailure(errmsg, code, response, max_wire_version)
#
# OperationFailure: Authentication failed., full error: {'ok': 0.0, 'errmsg': 'Authentication failed.', 'code': 18, 'codeName': 'AuthenticationFailed'}
